# %% [markdown]
# <a href="https://colab.research.google.com/github/dacasfilipe/Python_data_science/blob/main/exercicios_16_07_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Considere as seguintes instruções:
#
# arquivo = open('file1.txt', 'r')
# print(arquivo)
# arquivo.close()
#
# Considerando que o arquivo exista no caminho local indicado, qual será o resultado da instrução print()?
#
# a.
# Apenas a pasta em que o arquivo está localizado.
#
#
# b.
# Um mensagem de erro ('Traceback'), pois não é possível chamar a função print() passando como argumento a variável arquivo.
#
#
# c.
# O conteúdo do arquivo indicado.
#
#
# d.
# O identificador do arquivo, indicando que o arquivo solicitado existe e o usuário possui as permissões necessárias para acessá-lo.
#
# Questão 2
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Principal bilioteca para análise de dados no Python. Possui duas estruturas principais que são as Series(um dimensão) e o DataFrame (duas dimensões):
#
#
# a.
# scikit-learn
#
#
# b.
# seaborn
#
#
# c.
# statsmodels
#
#
# d.
# pandas
#
# Questão 3
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Considere as seguintes instruções:
#
# texto = 'Ciência de Dados'
# parte1 = texto[10:]
# print(parte1)
#
# O que será apresentado na tela por meio da instrução print()?
#
#
#
#
#
#
#
#
# a.
# Ciência
#
#
# b.
# Ciência de Dados
#
#
# c.
# de Dados
#
#
# d.
# Dados
#
# Questão 4
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Os três módulos mais comuns para trabalhar com datas e horas no Python são:
#
#
# a.
# calendar
#
#
# b.
# datetime
#
#
# c.
# time
#
#
# d.
# timezone
#
# Questão 5
# Parcialmente correto
# Atingiu 6,67 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Considere a instrução abaixo:
#
# cidade_estado = 'Curitiba,PR'
#
# Selecione as alternativas que realizam de maneira adequada a extração apenas da cidade do texto contido na variável:
#
#
#
#
# a.
# apenas_cidade, _ = cidade_estado.split(',')
#
# b.
# apenas_cidade = cidade_estado[0:cidade_estado.find(',')-1]
#
# c.
# apenas_cidade = cidade_estado[0:len(cidade_estado)-3]
#
# d.
# apenas_cidade = cidade_estado[0:cidade_estado.find(',')]
# Questão 6
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Principal biblioteca para implementação de modelos de Machine Learning no Python. Além disso, suporta modelos de Aprendizagem Supervisionada e Não Supervisionada.
#
#
# a.
# statsmodels
#
#
# b.
# numpy
#
#
# c.
# pandas
#
#
# d.
# scikit-learn
#
# Questão 7
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Considere as seguintes instruções:
#
# texto = 'inteligência Artificial'
# texto[0] = 'I'
# print(texto)
#
#
# Qual será o resultado da execução das instruções acima?
#
#
#
#
#
#
#
#
# a.
# Um mensagem de erro (Traceback), pois os elementos de uma string não podem ser lidos por meio da indicação de seus respectivos índices.
#
#
# b.
# Um mensagem de erro (Traceback), pois os elementos de uma string não podem ser alterados por meio da indicação de seus respectivos índices.
#
#
# c.
# O texto de saída 'inteligência Artificial' sem qualquer alteração.
#
#
# d.
# O texto de saída 'Inteligência Artificial' exibido por meio da instrução print();
#
# Questão 8
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Selecione as alternativas possíveis para leitura de um arquivo delimitado por vírgulas (.csv):
#
#
# a.
# Por meio do método genfromtxt() da bilbioteca numpy.
#
#
# b.
# Por meio da instrução embutida open() do Python.
#
#
# c.
# Por meio do método read_csv() da bilbioteca pandas.
#
#
# d.
# Por meio do método read_json() da bilioteca pandas.
#
# Questão 9
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Principais biliotecas do Python em atividades de visualização de dados em Data Science:
#
#
# a.
# matplotlib
#
#
# b.
# scikit-learn
#
#
# c.
# pandas
#
#
# d.
# seaborn
#
# Questão 10
# Correto
# Atingiu 10,00 de 10,00
# Não marcadaMarcar questão
# Texto da questão
# Bibloteca amplamente utilizada no Python cujo principal objetivo é a realização de atividades de processamento numérico em aplicações científicas:
#
#
# a.
# scikit-learn
#
#
# b.
# numpy
#
#
# c.
# matplotlib
#
#
# d.
# pandas
#
# Terminar revisão
