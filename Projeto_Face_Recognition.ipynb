# %% [markdown]
# <a href="https://colab.research.google.com/github/dacasfilipe/Python_data_science/blob/main/Projeto_Face_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# instalação do python: importante: ao instalar o python entre em advanced options e marque as opções conforme a imagem abaixo:
# https://www.python.org/downloads/
#
# ![python_install.PNG](data:image/png;base64,...)

# %% [markdown]
# # Projeto Face Recognition

# %% [markdown]
# instalaç"ao do visual studio for c++:
# https://learn.microsoft.com/en-us/cpp/build/vscpp-step-0-installation?view=msvc-170
#
# Abrir o projeto do github:
#
# instalar o cmake:
# importante: ao instalar adicionar ao PAth para todos usuários
# https://cmake.org/download/
# ![cmake.PNG](data:image/png;base64,...)
#
# após instalar o cmake abrir o projeto no vscode ou pycharm e instalar as bibliotecas através dos comandos abaixo no terminal:
# pip install dlib && pip install face_recognition && pip install numpy && pip install opencv-python

# %% [markdown]
# ### Instalação do microsoft visual studio comunity:
# https://visualstudio.microsoft.com/pt-br/thank-you-downloading-visual-studio/?sku=Community&channel=Release&version=VS2022&source=VSLandingPage&cid=2030&workload=dotnet-dotnetwebcloud&passive=false#dotnet
#
# marque os itens conforme na imagem abaixo:
# ![visual_studio_install.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Se nada funcionar faça isso a seguir,
# Abrir o powershell do windows em modo administrador:
# rodar o comando:
#
# Set-ExecutionPolicy Bypass -Scope Process -Force; [System.Net.ServicePointManager]::SecurityProtocol = [System.Net.ServicePointManager]::SecurityProtocol -bor 3072; iex ((New-Object System.Net.WebClient).DownloadString('https://community.chocolatey.org/install.ps1'))
#
# isso vai instalar o chocolately
# https://chocolatey.org/install
#
# digite choco na linha de comando e vai aparecer:
# choco
# Chocolatey v2.2.2
# Please run 'choco -?' or 'choco <command> -?' for help menu. **negrito** ***negrito*** *texto em itálico*
#
# Feito isso siga as instruções do guia do mochileiro Python:
# https://docs.python-guide.org/starting/install3/win/#install3-windows
#
# fazer o update do setup tools no python3:
# python3 -m pip install --upgrade pip setuptools wheel

# %% [markdown]
# # Erros de pip e python não reconhecido
#
# https://dicasdeprogramacao.com.br/resolvido-pip-nao-e-reconhecido-como-um-comando-interno/#:~:text=Uma%20situa%C3%A7%C3%A3o%20que%20pode%20acontecer,precisa%20instalar%20o%20pip%20al%C3%AD.
#
# https://dicasdeprogramacao.com.br/resolvido-pip-nao-e-reconhecido-como-um-comando-interno/
#
# pip install opencv-contrib-python
