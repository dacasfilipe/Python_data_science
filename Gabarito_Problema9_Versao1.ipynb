# %%
import numpy as np
# Dicionário para armazenar os resultados dos jogos
resultados_jogos = np.zeros((5,2))

# Variáveis para contagem das vitórias, empates e saldo de gols de cada time
vitorias_avai = 0
vitorias_figueirense = 0
empates = 0
saldo_gols_avai = 0
saldo_gols_figueirense = 0

# Loop para entrada dos resultados dos jogos
for jogo in range(0, 5):
    partida = input(f"Digite o resultado do jogo {jogo+1} (Avaí x Figueirense): ").upper()
    placar1, placar2 = partida.split("X")
    resultado_avai = int(placar1)
    resultado_figueirense = int(placar2)

    resultados_jogos[jogo][0] = resultado_avai
    resultados_jogos[jogo][1] = resultado_figueirense

    if resultado_avai > resultado_figueirense:
        vitorias_avai += 1
    elif resultado_figueirense > resultado_avai:
        vitorias_figueirense += 1
    else:
        empates += 1

    saldo_gols_avai += resultado_avai - resultado_figueirense
    saldo_gols_figueirense += resultado_figueirense - resultado_avai

# Exibe as informações dos jogos
print("\n=== Resultados dos Jogos ===")
for i in range(0,5):
    resultado_avai = resultados_jogos[i][0]
    resultado_figueirense = resultados_jogos[i][1]
    print(f"Jogo {jogo} (Avaí x Figueirense): {int(resultado_avai)} x {int(resultado_figueirense)}")

# Exibe as informações finais
print(resultados_jogos)
print("\n=== Estatísticas ===")
print("Quantidade de vitórias do Avaí:", vitorias_avai)
print("Quantidade de vitórias do Figueirense:", vitorias_figueirense)
print("Quantidade de empates:", empates)
print("Saldo de gols do Avaí:", saldo_gols_avai)
print("Saldo de gols do Figueirense:", saldo_gols_figueirense)
# Out:
# Digite o resultado do jogo 1 (Avaí x Figueirense): 1x1
# Digite o resultado do jogo 2 (Avaí x Figueirense): 2x1
# Digite o resultado do jogo 3 (Avaí x Figueirense): 3x2
# Digite o resultado do jogo 4 (Avaí x Figueirense): 4x3
# Digite o resultado do jogo 5 (Avaí x Figueirense): 2x2
#
# === Resultados dos Jogos ===
# Jogo 4 (Avaí x Figueirense): 1 x 1
# Jogo 4 (Avaí x Figueirense): 2 x 1
# Jogo 4 (Avaí x Figueirense): 3 x 2
# Jogo 4 (Avaí x Figueirense): 4 x 3
# Jogo 4 (Avaí x Figueirense): 2 x 2
# [[1. 1.]
#  [2. 1.]
#  [3. 2.]
#  [4. 3.]
#  [2. 2.]]
#
# === Estatísticas ===
# Quantidade de vitórias do Avaí: 3
# Quantidade de vitórias do Figueirense: 0
# Quantidade de empates: 2
# Saldo de gols do Avaí: 3
# Saldo de gols do Figueirense: -3
